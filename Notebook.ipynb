# %% [markdown]
# # AI-powered Resume Classification using NLP & ML Project

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
